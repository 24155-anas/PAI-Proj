# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# %%
# =========================================================
# CONFIG
# =========================================================

DATASET_PATH = "/kaggle/input/datasets/nexuswho/tomatofruits/Three Classes"

IMG_SIZE = 128
BATCH_SIZE = 16
EPOCHS = 100
LR = 0.001

# ✅ NOW USING 3 CLASSES
CLASS_NAMES = ["Ripe", "Unripe", "Reject"]
NUM_CLASSES = len(CLASS_NAMES)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Device:", device)
# Out:
# Device: cuda

# %%
# =========================================================
# DATASET CLASS
# =========================================================

class CustomDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = Image.open(self.image_paths[idx]).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            img = self.transform(img)

        return img, label

# %%
# =========================================================
# LOAD DATA (KAGGLE VERSION)
# =========================================================

def load_paths():
    paths = []
    labels = []

    for i, cls in enumerate(CLASS_NAMES):
        folder = os.path.join(DATASET_PATH, cls)

        for file in os.listdir(folder):
            paths.append(os.path.join(folder, file))
            labels.append(i)

    return np.array(paths), np.array(labels)


paths, labels = load_paths()

print("Total images:", len(paths))
# Out:
# Total images: 2400

# %%
X_train, X_test, y_train, y_test = train_test_split(
    paths,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

print(f"Train: {len(X_train)}, Test: {len(X_test)}")
# Out:
# Train: 1920, Test: 480

# %%
train_tf = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.2),
    transforms.ToTensor()
])

test_tf = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor()
])

train_ds = CustomDataset(X_train, y_train, train_tf)
test_ds = CustomDataset(X_test, y_test, test_tf)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
class TinyVGG(nn.Module):
    def __init__(self):
        super().__init__()

        self.block1 = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.block2 = nn.Sequential(
            nn.Conv2d(16, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.block3 = nn.Sequential(
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * (IMG_SIZE // 8) * (IMG_SIZE // 8), 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, NUM_CLASSES)
        )

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        return self.classifier(x)


model = TinyVGG().to(device)
print(model)
# Out:
# TinyVGG(
#   (block1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=16384, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
def train(model, loader, optimizer, loss_fn):
    model.train()
    total_loss, correct = 0, 0

    for X, y in loader:
        X, y = X.to(device), y.to(device)

        optimizer.zero_grad()
        preds = model(X)
        loss = loss_fn(preds, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        correct += (preds.argmax(1) == y).sum().item()

    return total_loss / len(loader), correct / len(loader.dataset)


def evaluate(model, loader, loss_fn):
    model.eval()
    total_loss, correct = 0, 0

    all_preds, all_labels = [], []

    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)

            preds = model(X)
            loss = loss_fn(preds, y)

            total_loss += loss.item()

            predicted = preds.argmax(1)
            correct += (predicted == y).sum().item()

            all_preds.append(predicted.cpu())
            all_labels.append(y.cpu())

    return (
        total_loss / len(loader),
        correct / len(loader.dataset),
        torch.cat(all_preds),
        torch.cat(all_labels)
    )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

for epoch in range(EPOCHS):
    train_loss, train_acc = train(model, train_loader, optimizer, loss_fn)

    print(f"Epoch {epoch+1}")
    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print("-" * 40)
# Out:
# Epoch 1
# Train Loss: 1.2690 | Train Acc: 0.4339
# ----------------------------------------
# Epoch 2
# Train Loss: 0.9286 | Train Acc: 0.5234
# ----------------------------------------
# Epoch 3
# Train Loss: 0.9247 | Train Acc: 0.5297
# ----------------------------------------
# Epoch 4
# Train Loss: 0.8870 | Train Acc: 0.5448
# ----------------------------------------
# Epoch 5
# Train Loss: 0.8836 | Train Acc: 0.5552
# ----------------------------------------
# Epoch 6
# Train Loss: 0.8729 | Train Acc: 0.5708
# ----------------------------------------
# Epoch 7
# Train Loss: 0.8857 | Train Acc: 0.5641
# ----------------------------------------
# Epoch 8
# Train Loss: 0.8417 | Train Acc: 0.5911
# ----------------------------------------
# Epoch 9
# Train Loss: 0.8416 | Train Acc: 0.5818
# ----------------------------------------
# Epoch 10
# Train Loss: 0.8601 | Train Acc: 0.5693
# ----------------------------------------
# Epoch 11
# Train Loss: 0.8289 | Train Acc: 0.5854
# ----------------------------------------
# Epoch 12
# Train Loss: 0.8315 | Train Acc: 0.5906
# ----------------------------------------
# Epoch 13
# Train Loss: 0.8256 | Train Acc: 0.5953
# ----------------------------------------
# Epoch 14
# Train Loss: 0.8126 | Train Acc: 0.6099
# ----------------------------------------
# Epoch 15
# Train Loss: 0.8207 | Train Acc: 0.6120
# ----------------------------------------
# Epoch 16
# Train Loss: 0.7961 | Train Acc: 0.6188
# ----------------------------------------
# Epoch 17
# Train Loss: 0.8096 | Train Acc: 0.6109
# ----------------------------------------
# Epoch 18
# Train Loss: 0.8041 | Train Acc: 0.6391
# ----------------------------------------
# Epoch 19
# Train Loss: 0.7653 | Train Acc: 0.6333
# ----------------------------------------
# Epoch 20
# Train Loss: 0.7575 | Train Acc: 0.6760
# ----------------------------------------
# Epoch 21
# Train Loss: 0.7647 | Train Acc: 0.6349
# ----------------------------------------
# Epoch 22
# Train Loss: 0.7562 | Train Acc: 0.6516
# ----------------------------------------
# Epoch 23
# Train Loss: 0.7264 | Train Acc: 0.6714
# ----------------------------------------
# Epoch 24
# Train Loss: 0.7465 | Train Acc: 0.6620
# ----------------------------------------
# Epoch 25
# Train Loss: 0.7431 | Train Acc: 0.6625
# ----------------------------------------
# Epoch 26
# Train Loss: 0.7333 | Train Acc: 0.6781
# ----------------------------------------
# Epoch 27
# Train Loss: 0.7095 | Train Acc: 0.6823
# ----------------------------------------
# Epoch 28
# Train Loss: 0.7296 | Train Acc: 0.6714
# ----------------------------------------
# Epoch 29
# Train Loss: 0.7049 | Train Acc: 0.6911
# ----------------------------------------
# Epoch 30
# Train Loss: 0.7182 | Train Acc: 0.6802
# ----------------------------------------
# Epoch 31
# Train Loss: 0.6961 | Train Acc: 0.6979
# ----------------------------------------
# Epoch 32
# Train Loss: 0.7348 | Train Acc: 0.6823
# ----------------------------------------
# Epoch 33
# Train Loss: 0.7211 | Train Acc: 0.6833
# ----------------------------------------
# Epoch 34
# Train Loss: 0.6895 | Train Acc: 0.6974
# ----------------------------------------
# Epoch 35
# Train Loss: 0.6896 | Train Acc: 0.6792
# ----------------------------------------
# Epoch 36
# Train Loss: 0.6829 | Train Acc: 0.7031
# ----------------------------------------
# Epoch 37
# Train Loss: 0.6755 | Train Acc: 0.7036
# ----------------------------------------
# Epoch 38
# Train Loss: 0.6718 | Train Acc: 0.7099
# ----------------------------------------
# Epoch 39
# Train Loss: 0.6866 | Train Acc: 0.6964
# ----------------------------------------
# Epoch 40
# Train Loss: 0.6504 | Train Acc: 0.7151
# ----------------------------------------
# Epoch 41
# Train Loss: 0.6531 | Train Acc: 0.7083
# ----------------------------------------
# Epoch 42
# Train Loss: 0.6486 | Train Acc: 0.7135
# ----------------------------------------
# Epoch 43
# Train Loss: 0.6853 | Train Acc: 0.7083
# ----------------------------------------
# Epoch 44
# Train Loss: 0.6437 | Train Acc: 0.7172
# ----------------------------------------
# Epoch 45
# Train Loss: 0.6684 | Train Acc: 0.7161
# ----------------------------------------
# Epoch 46
# Train Loss: 0.6392 | Train Acc: 0.7177
# ----------------------------------------
# Epoch 47
# Train Loss: 0.6423 | Train Acc: 0.7203
# ----------------------------------------
# Epoch 48
# Train Loss: 0.6550 | Train Acc: 0.7245
# ----------------------------------------
# Epoch 49
# Train Loss: 0.6271 | Train Acc: 0.7214
# ----------------------------------------
# Epoch 50
# Train Loss: 0.6313 | Train Acc: 0.7312
# ----------------------------------------
# Epoch 51
# Train Loss: 0.6511 | Train Acc: 0.7172
# ----------------------------------------
# Epoch 52
# Train Loss: 0.6269 | Train Acc: 0.7339
# ----------------------------------------
# Epoch 53
# Train Loss: 0.6119 | Train Acc: 0.7255
# ----------------------------------------
# Epoch 54
# Train Loss: 0.6305 | Train Acc: 0.7188
# ----------------------------------------
# Epoch 55
# Train Loss: 0.6184 | Train Acc: 0.7161
# ----------------------------------------
# Epoch 56
# Train Loss: 0.6190 | Train Acc: 0.7339
# ----------------------------------------
# Epoch 57
# Train Loss: 0.6268 | Train Acc: 0.7349
# ----------------------------------------
# Epoch 58
# Train Loss: 0.5801 | Train Acc: 0.7349
# ----------------------------------------
# Epoch 59
# Train Loss: 0.6046 | Train Acc: 0.7401
# ----------------------------------------
# Epoch 60
# Train Loss: 0.6285 | Train Acc: 0.7198
# ----------------------------------------
# Epoch 61
# Train Loss: 0.6134 | Train Acc: 0.7333
# ----------------------------------------
# Epoch 62
# Train Loss: 0.6111 | Train Acc: 0.7286
# ----------------------------------------
# Epoch 63
# Train Loss: 0.5889 | Train Acc: 0.7344
# ----------------------------------------
# Epoch 64
# Train Loss: 0.5939 | Train Acc: 0.7396
# ----------------------------------------
# Epoch 65
# Train Loss: 0.5976 | Train Acc: 0.7312
# ----------------------------------------
# Epoch 66
# Train Loss: 0.5966 | Train Acc: 0.7380
# ----------------------------------------
# Epoch 67
# Train Loss: 0.5948 | Train Acc: 0.7474
# ----------------------------------------
# Epoch 68
# Train Loss: 0.6285 | Train Acc: 0.7292
# ----------------------------------------
# Epoch 69
# Train Loss: 0.6226 | Train Acc: 0.7188
# ----------------------------------------
# Epoch 70
# Train Loss: 0.6111 | Train Acc: 0.7495
# ----------------------------------------
# Epoch 71
# Train Loss: 0.5923 | Train Acc: 0.7307
# ----------------------------------------
# Epoch 72
# Train Loss: 0.5947 | Train Acc: 0.7391
# ----------------------------------------
# Epoch 73
# Train Loss: 0.5835 | Train Acc: 0.7312
# ----------------------------------------
# Epoch 74
# Train Loss: 0.5896 | Train Acc: 0.7396
# ----------------------------------------
# Epoch 75
# Train Loss: 0.5927 | Train Acc: 0.7286
# ----------------------------------------
# Epoch 76
# Train Loss: 0.5921 | Train Acc: 0.7458
# ----------------------------------------
# Epoch 77
# Train Loss: 0.6249 | Train Acc: 0.7292
# ----------------------------------------
# Epoch 78
# Train Loss: 0.6011 | Train Acc: 0.7286
# ----------------------------------------
# Epoch 79
# Train Loss: 0.5897 | Train Acc: 0.7500
# ----------------------------------------
# Epoch 80
# Train Loss: 0.5813 | Train Acc: 0.7469
# ----------------------------------------
# Epoch 81
# Train Loss: 0.5772 | Train Acc: 0.7385
# ----------------------------------------
# Epoch 82
# Train Loss: 0.5671 | Train Acc: 0.7547
# ----------------------------------------
# Epoch 83
# Train Loss: 0.5888 | Train Acc: 0.7427
# ----------------------------------------
# Epoch 84
# Train Loss: 0.5605 | Train Acc: 0.7531
# ----------------------------------------
# Epoch 85
# Train Loss: 0.5897 | Train Acc: 0.7448
# ----------------------------------------
# Epoch 86
# Train Loss: 0.5907 | Train Acc: 0.7526
# ----------------------------------------
# Epoch 87
# Train Loss: 0.5656 | Train Acc: 0.7578
# ----------------------------------------
# Epoch 88
# Train Loss: 0.5488 | Train Acc: 0.7453
# ----------------------------------------
# Epoch 89
# Train Loss: 0.5838 | Train Acc: 0.7417
# ----------------------------------------
# Epoch 90
# Train Loss: 0.5668 | Train Acc: 0.7552
# ----------------------------------------
# Epoch 91
# Train Loss: 0.5633 | Train Acc: 0.7594
# ----------------------------------------
# Epoch 92
# Train Loss: 0.5925 | Train Acc: 0.7354
# ----------------------------------------
# Epoch 93
# Train Loss: 0.5806 | Train Acc: 0.7396
# ----------------------------------------
# Epoch 94
# Train Loss: 0.5597 | Train Acc: 0.7479
# ----------------------------------------
# Epoch 95
# Train Loss: 0.5651 | Train Acc: 0.7464
# ----------------------------------------
# Epoch 96
# Train Loss: 0.5675 | Train Acc: 0.7411
# ----------------------------------------
# Epoch 97
# Train Loss: 0.5659 | Train Acc: 0.7526
# ----------------------------------------
# Epoch 98
# Train Loss: 0.5838 | Train Acc: 0.7406
# ----------------------------------------
# Epoch 99
# Train Loss: 0.5657 | Train Acc: 0.7521
# ----------------------------------------
# Epoch 100
# Train Loss: 0.5402 | Train Acc: 0.7651
# ----------------------------------------

# %%
test_loss, test_acc, preds, labels = evaluate(model, test_loader, loss_fn)

print("\nTEST ACC:", test_acc)

print("\nClassification Report")
print(classification_report(labels, preds, target_names=CLASS_NAMES))
# Out:
# TEST ACC: 0.8125
#
# Classification Report
#               precision    recall  f1-score   support
#
#         Ripe       0.94      0.57      0.71       160
#       Unripe       0.93      0.95      0.94       160
#       Reject       0.67      0.91      0.77       160
#
#     accuracy                           0.81       480
#    macro avg       0.85      0.81      0.81       480
# weighted avg       0.85      0.81      0.81       480

# %%
cm = confusion_matrix(labels, preds)

plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix")
plt.colorbar()

for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xticks(range(NUM_CLASSES), CLASS_NAMES)
plt.yticks(range(NUM_CLASSES), CLASS_NAMES)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
